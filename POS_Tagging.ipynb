# %%
import spacy
import re
import glob
nlp = spacy.load("en_core_web_sm")
path="/content/big.txt"
for file in glob.glob(path):
    with open(file, encoding='utf-8', errors='ignore') as file_in:
        text = file_in.read()
        words_pattern = '[a-zA-Z]+'
        lines = re.findall(words_pattern, text, flags=re.IGNORECASE)
        for line in lines:
            line = nlp(line)
            for token in line:
              if spacy.explain(token.pos_)=='noun' or spacy.explain(token.pos_)=='adverb':
                  print(token,":",spacy.explain(token.pos_))
# Out:
# Project : noun
# Adventures : noun
# Holmes : noun
# Sir : noun
# Doyle : noun
# Sir : noun
# Doyle : noun
# Copyright : noun
# laws : noun
# world : noun
# copyright : noun
# laws : noun
# country : noun
# Project : noun
# eBook : noun
# first : adverb
# thing : noun
# Project : noun
# file : noun
# permission : noun
# print : noun
# information : noun
# eBook : noun
# Project : noun
# file : noun
# information : noun
# rights : noun
# restrictions : noun
# file : noun
# also : adverb
# donation : noun
# Project : noun
# World : noun
# Vanilla : noun
# Texts : noun
# eBooks : noun
# Humans : noun
# Computers : noun
# eBooks : noun
# Thousands : noun
# Volunteers : noun
# Title : noun
# Adventures : noun
# Holmes : noun
# Author : noun
# Sir : noun
# Doyle : noun
# Release : noun
# Date : noun
# recently : adverb
# Edition : noun
# Language : noun
# Character : noun
# ASCII : noun
# GUTENBERG : noun
# EBOOK : noun
# Jose : noun
# ARTHUR : noun
# DOYLE : noun
# CONTENTS : noun
# Scandal : noun
# Bohemia : noun
# II : noun
# League : noun
# Case : noun
# Identity : noun
# Valley : noun
# Mystery : noun
# V : noun
# Pips : noun
# Man : noun
# Lip : noun
# Adventure : noun
# Carbuncle : noun
# Adventure : noun
# Band : noun
# Adventure : noun
# Engineer : noun
# s : noun
# Thumb : noun
# X : noun
# Adventure : noun
# Bachelor : noun
# Adventure : noun
# Beryl : noun
# Adventure : noun
# Copper : noun
# Beeches : noun
# ADVENTURE : noun
# SCANDAL : noun
# BOHEMIA : noun
# Holmes : noun
# always : adverb
# woman : noun
# seldom : adverb
# name : noun
# eyes : noun
# eclipses : noun
# sex : noun
# emotion : noun
# love : noun
# emotions : noun
# particularly : adverb
# admirably : adverb
# reasoning : noun
# machine : noun
# world : noun
# position : noun
# never : adverb
# passions : noun
# things : noun
# observer : noun
# men : noun
# s : noun
# motives : noun
# actions : noun
# reasoner : noun
# intrusions : noun
# finely : adverb
# temperament : noun
# factor : noun
# results : noun
# Grit : noun
# instrument : noun
# power : noun
# lenses : noun
# emotion : noun
# nature : noun
# yet : adverb
# there : adverb
# woman : noun
# woman : noun
# late : adverb
# memory : noun
# Holmes : noun
# lately : adverb
# marriage : noun
# away : adverb
# happiness : noun
# home : noun
# interests : noun
# around : adverb
# man : noun
# first : adverb
# establishment : noun
# attention : noun
# Holmes : noun
# form : noun
# society : noun
# soul : noun
# lodgings : noun
# Street : noun
# books : noun
# week : noun
# week : noun
# cocaine : noun
# ambition : noun
# drug : noun
# energy : noun
# nature : noun
# still : adverb
# ever : adverb
# deeply : adverb
# crime : noun
# faculties : noun
# powers : noun
# observation : noun
# clues : noun
# mysteries : noun
# official : noun
# police : noun
# time : noun
# time : noun
# account : noun
# doings : noun
# summons : noun
# Odessa : noun
# case : noun
# murder : noun
# tragedy : noun
# Atkinson : noun
# brothers : noun
# finally : adverb
# mission : noun
# so : adverb
# delicately : adverb
# successfully : adverb
# family : noun
# signs : noun
# activity : noun
# however : adverb
# merely : adverb
# readers : noun
# press : noun
# friend : noun
# companion : noun
# night : noun
# patient : noun
# now : adverb
# way : noun
# Street : noun
# door : noun
# always : adverb
# incidents : noun
# Study : noun
# Scarlet : noun
# desire : noun
# Holmes : noun
# again : adverb
# powers : noun
# rooms : noun
# brilliantly : adverb
# even : adverb
# figure : noun
# twice : adverb
# room : noun
# swiftly : adverb
# eagerly : adverb
# head : noun
# chest : noun
# hands : noun
# behind : adverb
# mood : noun
# habit : noun
# attitude : noun
# story : noun
# work : noun
# again : adverb
# drug : noun
# scent : noun
# problem : noun
# formerly : adverb
# part : noun
# seldom : adverb
# hardly : adverb
# word : noun
# kindly : adverb
# eye : noun
# armchair : noun
# case : noun
# case : noun
# gasogene : noun
# Then : adverb
# fire : noun
# fashion : noun
# Wedlock : noun
# suits : noun
# Watson : noun
# half : noun
# pounds : noun
# Indeed : adverb
# Just : adverb
# trifle : adverb
# Watson : noun
# again : adverb
# harness : noun
# Then : adverb
# very : adverb
# lately : adverb
# servant : noun
# girl : noun
# Holmes : noun
# too : adverb
# certainly : adverb
# centuries : noun
# ago : adverb
# country : noun
# home : noun
# mess : noun
# clothes : noun
# wife : noun
# notice : noun
# there : adverb
# again : adverb
# work : noun
# long : adverb
# hands : noun
# together : adverb
# simplicity : noun
# eyes : noun
# inside : adverb
# just : adverb
# firelight : noun
# strikes : noun
# leather : noun
# almost : adverb
# cuts : noun
# Obviously : adverb
# very : adverb
# carelessly : adverb
# round : adverb
# edges : noun
# order : noun
# mud : noun
# Hence : adverb
# deduction : noun
# weather : noun
# particularly : adverb
# boot : noun
# specimen : noun
# slavey : noun
# gentleman : noun
# rooms : noun
# iodoform : adverb
# mark : noun
# silver : noun
# right : adverb
# right : adverb
# side : noun
# hat : noun
# indeed : adverb
# pronounce : noun
# member : noun
# profession : noun
# ease : noun
# process : noun
# deduction : noun
# reasons : noun
# thing : noun
# always : adverb
# so : adverb
# ridiculously : adverb
# easily : adverb
# instance : noun
# reasoning : noun
# process : noun
# yet : adverb
# eyes : noun
# yours : noun
# so : adverb
# cigarette : noun
# down : adverb
# armchair : noun
# distinction : noun
# example : noun
# frequently : adverb
# steps : noun
# room : noun
# Frequently : adverb
# often : adverb
# hundreds : noun
# times : noun
# Then : adverb
# there : adverb
# so : adverb
# yet : adverb
# just : adverb
# point : noun
# Now : adverb
# there : adverb
# steps : noun
# way : noun
# problems : noun
# enough : adverb
# chronicle : noun
# experiences : noun
# sheet : noun
# notepaper : adverb
# table : noun
# either : adverb
# signature : noun
# address : noun
# There : adverb
# night : noun
# quarter : noun
# clock : noun
# gentleman : noun
# desires : noun
# very : adverb
# moment : noun
# services : noun
# houses : noun
# safely : adverb
# matters : noun
# importance : noun
# hardly : adverb
# account : noun
# quarters : noun
# then : adverb
# hour : noun
# visitor : noun
# mask : noun
# indeed : adverb
# mystery : noun
# data : noun
# yet : adverb
# capital : noun
# theorise : noun
# data : noun
# Insensibly : adverb
# theories : noun
# instead : adverb
# theories : noun
# carefully : adverb
# paper : noun
# man : noun
# presumably : adverb
# companion : noun
# s : noun
# processes : noun
# paper : noun
# half : noun
# crown : noun
# packet : noun
# peculiarly : adverb
# very : adverb
# word : noun
# Holmes : noun
# paper : noun
# so : adverb
# E : noun
# P : noun
# G : noun
# paper : noun
# Holmes : noun
# name : noun
# maker : noun
# rather : adverb
# G : noun
# Gesellschaft : noun
# Company : noun
# contraction : noun
# Co : noun
# P : noun
# course : noun
# Now : adverb
# glance : noun
# Gazetteer : noun
# down : adverb
# volume : noun
# shelves : noun
# Eglonitz : noun
# here : adverb
# country : noun
# Bohemia : noun
# far : adverb
# scene : noun
# death : noun
# glass : noun
# factories : noun
# paper : noun
# mills : noun
# eyes : noun
# cigarette : noun
# paper : noun
# Bohemia : noun
# Precisely : adverb
# man : noun
# construction : noun
# sentence : noun
# account : noun
# quarters : noun
# Frenchman : noun
# so : adverb
# verbs : noun
# only : adverb
# therefore : adverb
# paper : noun
# mask : noun
# face : noun
# here : adverb
# doubts : noun
# there : adverb
# sound : noun
# horses : noun
# hoofs : noun
# wheels : noun
# Holmes : noun
# sound : noun
# beauties : noun
# guineas : noun
# apiece : adverb
# There : adverb
# s : noun
# money : noun
# case : noun
# Watson : noun
# there : adverb
# else : adverb
# better : adverb
# Holmes : noun
# bit : noun
# Doctor : noun
# pity : noun
# client : noun
# Never : adverb
# so : adverb
# Here : adverb
# down : adverb
# armchair : noun
# Doctor : noun
# best : adverb
# attention : noun
# stairs : noun
# passage : noun
# immediately : adverb
# outside : adverb
# door : noun
# Then : adverb
# there : adverb
# tap : noun
# Holmes : noun
# man : noun
# hardly : adverb
# feet : noun
# inches : noun
# height : noun
# chest : noun
# limbs : noun
# Hercules : noun
# dress : noun
# taste : noun
# bands : noun
# sleeves : noun
# fronts : noun
# cloak : noun
# shoulders : noun
# flame : noun
# silk : noun
# neck : noun
# brooch : noun
# beryl : noun
# Boots : noun
# halfway : adverb
# calves : noun
# tops : noun
# fur : noun
# impression : noun
# opulence : noun
# appearance : noun
# hat : noun
# hand : noun
# part : noun
# face : noun
# down : adverb
# cheekbones : noun
# mask : noun
# apparently : adverb
# very : adverb
# moment : noun
# hand : noun
# still : adverb
# part : noun
# face : noun
# man : noun
# character : noun
# long : adverb
# straight : adverb
# resolution : noun
# length : noun
# obstinacy : noun
# voice : noun
# strongly : adverb
# accent : noun
# address : noun
# seat : noun
# Holmes : noun
# friend : noun
# Dr : noun
# Watson : noun
# occasionally : adverb
# enough : adverb
# cases : noun
# address : noun
# address : noun
# Von : noun
# gentleman : noun
# friend : noun
# man : noun
# discretion : noun
# importance : noun
# alone : adverb
# Holmes : noun
# wrist : noun
# back : adverb
# chair : noun
# none : noun
# gentleman : noun
# shoulders : noun
# Then : adverb
# secrecy : noun
# years : noun
# end : noun
# time : noun
# importance : noun
# too : adverb
# weight : noun
# influence : noun
# history : noun
# promise : noun
# Holmes : noun
# excuse : noun
# mask : noun
# visitor : noun
# person : noun
# employs : noun
# agent : noun
# once : adverb
# title : noun
# just : adverb
# exactly : adverb
# Holmes : noun
# dryly : adverb
# circumstances : noun
# delicacy : noun
# precaution : noun
# scandal : noun
# seriously : adverb
# compromise : noun
# families : noun
# plainly : adverb
# Ormstein : adverb
# kings : noun
# Bohemia : noun
# also : adverb
# Holmes : noun
# down : adverb
# armchair : noun
# eyes : noun
# visitor : noun
# surprise : noun
# figure : noun
# man : noun
# reasoner : noun
# agent : noun
# Holmes : noun
# slowly : adverb
# eyes : noun
# impatiently : adverb
# client : noun
# state : noun
# case : noun
# better : adverb
# advise : noun
# man : noun
# chair : noun
# down : adverb
# room : noun
# agitation : noun
# Then : adverb
# gesture : noun
# desperation : noun
# mask : noun
# face : noun
# ground : noun
# right : adverb
# King : noun
# attempt : noun
# conceal : noun
# indeed : adverb
# Holmes : noun
# Gottsreich : noun
# Ormstein : adverb
# Grand : noun
# Cassel : noun
# Felstein : noun
# King : noun
# Bohemia : noun
# visitor : noun
# down : adverb
# once : adverb
# hand : noun
# business : noun
# person : noun
# Yet : adverb
# so : adverb
# confide : noun
# agent : noun
# power : noun
# purpose : noun
# Then : adverb
# Holmes : noun
# eyes : noun
# once : adverb
# briefly : adverb
# years : noun
# ago : adverb
# acquaintance : noun
# adventuress : noun
# name : noun
# Kindly : adverb
# index : noun
# Doctor : noun
# Holmes : noun
# eyes : noun
# years : noun
# system : noun
# paragraphs : noun
# men : noun
# things : noun
# so : adverb
# name : noun
# person : noun
# once : adverb
# furnish : noun
# information : noun
# case : noun
# biography : noun
# staff : noun
# commander : noun
# sea : noun
# fishes : noun
# Holmes : noun
# year : noun
# Prima : noun
# Opera : noun
# stage : noun
# quite : adverb
# so : adverb
# person : noun
# letters : noun
# now : adverb
# letters : noun
# back : adverb
# Precisely : adverb
# so : adverb
# there : adverb
# marriage : noun
# None : noun
# papers : noun
# certificates : noun
# None : noun
# Then : adverb
# person : noun
# letters : noun
# purposes : noun
# authenticity : noun
# There : adverb
# Forgery : noun
# paper : noun
# photograph : noun
# photograph : noun
# very : adverb
# indeed : adverb
# seriously : adverb
# only : adverb
# Crown : noun
# Prince : noun
# then : adverb
# now : adverb
# then : adverb
# attempts : noun
# Twice : adverb
# Once : adverb
# luggage : noun
# Twice : adverb
# There : adverb
# Absolutely : adverb
# none : noun
# Holmes : noun
# quite : adverb
# pretty : adverb
# problem : noun
# very : adverb
# King : noun
# reproachfully : adverb
# Very : adverb
# indeed : adverb
# photograph : noun
# ruin : noun
# So : adverb
# Lothman : noun
# Saxe : noun
# second : adverb
# daughter : noun
# King : noun
# principles : noun
# family : noun
# very : adverb
# soul : noun
# delicacy : noun
# end : noun
# photograph : noun
# soul : noun
# steel : noun
# face : noun
# women : noun
# men : noun
# Rather : adverb
# woman : noun
# there : adverb
# lengths : noun
# none : noun
# yet : adverb
# day : noun
# publicly : adverb
# then : adverb
# days : noun
# yet : adverb
# Holmes : noun
# very : adverb
# matters : noun
# importance : noun
# just : adverb
# course : noun
# Certainly : adverb
# name : noun
# Von : noun
# Then : adverb
# line : noun
# so : adverb
# anxiety : noun
# Then : adverb
# money : noun
# blanche : noun
# Absolutely : adverb
# provinces : noun
# kingdom : noun
# photograph : noun
# expenses : noun
# King : noun
# leather : noun
# cloak : noun
# table : noun
# There : adverb
# pounds : noun
# gold : noun
# notes : noun
# Holmes : noun
# receipt : noun
# sheet : noun
# book : noun
# s : noun
# address : noun
# Serpentine : noun
# Avenue : noun
# St : noun
# s : noun
# Wood : noun
# Holmes : noun
# question : noun
# photograph : noun
# Then : adverb
# night : noun
# soon : adverb
# news : noun
# night : noun
# Watson : noun
# wheels : noun
# down : adverb
# enough : adverb
# morrow : noun
# afternoon : noun
# clock : noun
# II : noun
# clock : noun
# precisely : adverb
# Street : noun
# Holmes : noun
# yet : adverb
# shortly : adverb
# clock : noun
# morning : noun
# down : adverb
# beside : adverb
# fire : noun
# however : adverb
# intention : noun
# however : adverb
# long : adverb
# already : adverb
# deeply : adverb
# inquiry : noun
# none : noun
# features : noun
# crimes : noun
# already : adverb
# still : adverb
# nature : noun
# case : noun
# station : noun
# client : noun
# character : noun
# Indeed : adverb
# apart : adverb
# nature : noun
# investigation : noun
# friend : noun
# hand : noun
# there : adverb
# masterly : adverb
# situation : noun
# reasoning : noun
# pleasure : noun
# system : noun
# work : noun
# methods : noun
# mysteries : noun
# So : adverb
# success : noun
# very : adverb
# possibility : noun
# head : noun
# close : adverb
# door : noun
# ill : adverb
# side : noun
# face : noun
# clothes : noun
# room : noun
# friend : noun
# s : noun
# powers : noun
# disguises : noun
# times : noun
# indeed : adverb
# bedroom : noun
# whence : adverb
# minutes : noun
# hands : noun
# pockets : noun
# legs : noun
# front : noun
# fire : noun
# heartily : adverb
# minutes : noun
# really : adverb
# then : adverb
# again : adverb
# back : adverb
# chair : noun
# s : noun
# quite : adverb
# too : adverb
# never : adverb
# morning : noun
# habits : noun
# perhaps : adverb
# so : adverb
# sequel : noun
# rather : adverb
# however : adverb
# clock : noun
# morning : noun
# character : noun
# work : noun
# There : adverb
# freemasonry : noun
# men : noun
# there : adverb
# soon : adverb
# garden : noun
# back : adverb
# front : noun
# right : adverb
# road : noun
# stories : noun
# Chubb : noun
# door : noun
# room : noun
# right : adverb
# side : noun
# long : adverb
# windows : noun
# almost : adverb
# floor : noun
# fasteners : noun
# child : noun
# there : adverb
# passage : noun
# coach : noun
# round : adverb
# closely : adverb
# point : noun
# else : adverb
# interest : noun
# then : adverb
# down : adverb
# there : adverb
# lane : noun
# down : adverb
# garden : noun
# ostlers : noun
# hand : noun
# down : adverb
# horses : noun
# twopence : noun
# glass : noun
# half : noun
# half : noun
# fills : noun
# shag : noun
# information : noun
# desire : noun
# half : noun
# dozen : noun
# people : noun
# neighbourhood : noun
# biographies : noun
# men : noun
# s : noun
# heads : noun
# down : adverb
# part : noun
# thing : noun
# planet : noun
# So : adverb
# Serpentine : noun
# man : noun
# quietly : adverb
# sings : noun
# concerts : noun
# drives : noun
# day : noun
# returns : noun
# dinner : noun
# Seldom : adverb
# times : noun
# sings : noun
# only : adverb
# male : noun
# visitor : noun
# deal : noun
# never : adverb
# once : adverb
# day : noun
# often : adverb
# twice : adverb
# Godfrey : noun
# advantages : noun
# confidant : noun
# home : noun
# dozen : noun
# times : noun
# Serpentine : noun
# down : adverb
# near : adverb
# once : adverb
# campaign : noun
# Godfrey : noun
# evidently : adverb
# factor : noun
# lawyer : noun
# relation : noun
# object : noun
# visits : noun
# client : noun
# friend : noun
# mistress : noun
# probably : adverb
# photograph : noun
# likely : adverb
# issue : noun
# question : noun
# work : noun
# attention : noun
# gentleman : noun
# s : noun
# chambers : noun
# point : noun
# field : noun
# inquiry : noun
# details : noun
# difficulties : noun
# situation : noun
# closely : adverb
# still : adverb
# gentleman : noun
# remarkably : adverb
# man : noun
# evidently : adverb
# man : noun
# door : noun
# air : noun
# man : noun
# thoroughly : adverb
# home : noun
# half : noun
# hour : noun
# glimpses : noun
# windows : noun
# room : noun
# down : adverb
# excitedly : adverb
# arms : noun
# Presently : adverb
# even : adverb
# gold : noun
# pocket : noun
# earnestly : adverb
# first : adverb
# Gross : noun
# Hankey : noun
# s : noun
# Street : noun
# then : adverb
# Church : noun
# St : noun
# Road : noun
# minutes : noun
# Away : adverb
# just : adverb
# lane : noun
# landau : noun
# only : adverb
# half : noun
# ear : noun
# tags : noun
# harness : noun
# buckles : noun
# door : noun
# only : adverb
# glimpse : noun
# moment : noun
# lovely : adverb
# woman : noun
# face : noun
# man : noun
# Church : noun
# St : noun
# half : noun
# minutes : noun
# quite : adverb
# too : adverb
# Watson : noun
# just : adverb
# perch : noun
# behind : adverb
# landau : noun
# driver : noun
# twice : adverb
# fare : noun
# object : noun
# Church : noun
# St : noun
# half : noun
# minutes : noun
# minutes : noun
# course : noun
# enough : adverb
# wind : noun
# fast : adverb
# ever : adverb
# faster : adverb
# others : noun
# there : adverb
# landau : noun
# horses : noun
# front : noun
# door : noun
# man : noun
# church : noun
# There : adverb
# soul : noun
# there : adverb
# clergyman : noun
# knot : noun
# front : noun
# side : noun
# church : noun
# Suddenly : adverb
# surprise : noun
# round : adverb
# Godfrey : noun
# hard : adverb
# then : adverb
# man : noun
# only : adverb
# minutes : noun
# half : noun
# responses : noun
# ear : noun
# things : noun
# generally : adverb
# spinster : noun
# Godfrey : noun
# instant : noun
# there : adverb
# gentleman : noun
# side : noun
# clergyman : noun
# front : noun
# position : noun
# ever : adverb
# life : noun
# just : adverb
# now : adverb
# there : adverb
# informality : noun
# license : noun
# clergyman : noun
# absolutely : adverb
# sort : adverb
# appearance : noun
# streets : noun
# search : noun
# best : adverb
# man : noun
# chain : noun
# memory : noun
# occasion : noun
# very : adverb
# affairs : noun
# then : adverb
# plans : noun
# very : adverb
# seriously : adverb
# departure : noun
# so : adverb
# very : adverb
# measures : noun
# part : noun
# church : noun
# door : noun
# however : adverb
# back : adverb
# away : adverb
# directions : noun
# arrangements : noun
# beef : noun
# glass : noun
# beer : noun
# too : adverb
# food : noun
# likely : adverb
# still : adverb
# evening : noun
# way : noun
# Doctor : noun
# operation : noun
# law : noun
# chance : noun
# arrest : noun
# Then : adverb
# man : noun
# rely : adverb
# Now : adverb
# hungrily : adverb
# fare : noun
# time : noun
# nearly : adverb
# now : adverb
# hours : noun
# scene : noun
# action : noun
# Madame : noun
# rather : adverb
# returns : noun
# then : adverb
# already : adverb
# There : adverb
# only : adverb
# point : noun
# There : adverb
# probably : adverb
# unpleasantness : noun
# end : noun
# minutes : noun
# afterwards : adverb
# room : noun
# station : noun
# close : adverb
# hand : noun
# so : adverb
# room : noun
# time : noun
# fire : noun
# quite : adverb
# Entirely : adverb
# very : adverb
# long : adverb
# roll : noun
# pocket : noun
# s : noun
# smoke : noun
# rocket : noun
# cap : noun
# either : adverb
# end : noun
# self : noun
# task : noun
# fire : noun
# quite : adverb
# number : noun
# people : noun
# then : adverb
# end : noun
# minutes : noun
# near : adverb
# object : noun
# then : adverb
# fire : noun
# Precisely : adverb
# Then : adverb
# entirely : adverb
# rely : adverb
# perhaps : adverb
# almost : adverb
# time : noun
# role : noun
# bedroom : noun
# minutes : noun
# character : noun
# Nonconformist : noun
# clergyman : noun
# hat : noun
# trousers : noun
# smile : noun
# curiosity : noun
# alone : adverb
# merely : adverb
# Holmes : noun
# costume : noun
# expression : noun
# very : adverb
# soul : noun
# part : noun
# stage : noun
# actor : noun
# even : adverb
# science : noun
# reasoner : noun
# specialist : noun
# crime : noun
# quarter : noun
# Street : noun
# still : adverb
# minutes : noun
# hour : noun
# Serpentine : noun
# Avenue : noun
# already : adverb
# lamps : noun
# just : adverb
# down : adverb
# front : noun
# just : adverb
# Holmes : noun
# description : noun
# locality : noun
# contrary : adverb
# neighbourhood : noun
# remarkably : adverb
# There : adverb
# group : noun
# shabbily : adverb
# men : noun
# scissors : noun
# wheel : noun
# guardsmen : noun
# nurse : noun
# girl : noun
# men : noun
# down : adverb
# mouths : noun
# Holmes : noun
# front : noun
# marriage : noun
# rather : adverb
# simplifies : noun
# matters : noun
# photograph : noun
# weapon : noun
# now : adverb
# chances : noun
# averse : adverb
# Godfrey : noun
# client : noun
# eyes : noun
# Now : adverb
# question : noun
# photograph : noun
# indeed : adverb
# size : noun
# Too : adverb
# woman : noun
# s : noun
# dress : noun
# King : noun
# attempts : noun
# sort : adverb
# already : adverb
# then : adverb
# then : adverb
# banker : noun
# lawyer : noun
# There : adverb
# possibility : noun
# Women : noun
# naturally : adverb
# hand : noun
# else : adverb
# guardianship : noun
# influence : noun
# business : noun
# man : noun
# days : noun
# hands : noun
# twice : adverb
# Pshaw : noun
# then : adverb
# wheels : noun
# carriage : noun
# Now : adverb
# orders : noun
# letter : noun
# gleam : noun
# sidelights : noun
# carriage : noun
# round : adverb
# avenue : noun
# landau : noun
# door : noun
# men : noun
# forward : adverb
# door : noun
# copper : noun
# away : adverb
# intention : noun
# quarrel : noun
# guardsmen : noun
# sides : noun
# loungers : noun
# scissors : noun
# equally : adverb
# side : noun
# instant : noun
# carriage : noun
# centre : noun
# knot : noun
# men : noun
# savagely : adverb
# fists : noun
# sticks : noun
# Holmes : noun
# crowd : noun
# just : adverb
# ground : noun
# blood : noun
# freely : adverb
# down : adverb
# face : noun
# guardsmen : noun
# heels : noun
# direction : noun
# loungers : noun
# number : noun
# better : adverb
# people : noun
# scuffle : noun
# part : noun
# man : noun
# still : adverb
# steps : noun
# figure : noun
# lights : noun
# back : adverb
# gentleman : noun
# voices : noun
# there : adverb
# s : noun
# life : noun
# hospital : noun
# s : noun
# fellow : noun
# woman : noun
# s : noun
# purse : noun
# gang : noun
# too : adverb
# s : noun
# now : adverb
# Surely : adverb
# room : noun
# There : adverb
# sofa : noun
# way : noun
# Slowly : adverb
# solemnly : adverb
# principal : noun
# room : noun
# still : adverb
# proceedings : noun
# lamps : noun
# blinds : noun
# so : adverb
# Holmes : noun
# couch : noun
# compunction : noun
# moment : noun
# part : noun
# never : adverb
# heartily : adverb
# life : noun
# creature : noun
# grace : noun
# kindliness : noun
# man : noun
# yet : adverb
# treachery : noun
# Holmes : noun
# back : adverb
# now : adverb
# part : noun
# heart : noun
# smoke : noun
# rocket : noun
# Holmes : noun
# couch : noun
# motion : noun
# man : noun
# air : noun
# instant : noun
# hand : noun
# rocket : noun
# room : noun
# Fire : noun
# word : noun
# sooner : adverb
# mouth : noun
# crowd : noun
# spectators : noun
# ill : adverb
# gentlemen : noun
# ostlers : noun
# servant : noun
# Fire : noun
# clouds : noun
# smoke : noun
# room : noun
# glimpse : noun
# figures : noun
# moment : noun
# later : adverb
# voice : noun
# Holmes : noun
# crowd : noun
# way : noun
# minutes : noun
# friend : noun
# s : noun
# mine : noun
# away : adverb
# scene : noun
# swiftly : adverb
# silence : noun
# minutes : noun
# down : adverb
# streets : noun
# Road : noun
# very : adverb
# nicely : adverb
# Doctor : noun
# better : adverb
# right : adverb
# photograph : noun
# still : adverb
# mystery : noun
# perfectly : adverb
# course : noun
# accomplice : noun
# evening : noun
# Then : adverb
# row : noun
# paint : noun
# hand : noun
# forward : adverb
# down : adverb
# hand : noun
# face : noun
# spectacle : noun
# also : adverb
# Then : adverb
# else : adverb
# room : noun
# very : adverb
# room : noun
# bedroom : noun
# couch : noun
# air : noun
# chance : noun
# woman : noun
# fire : noun
# instinct : noun
# once : adverb
# rush : noun
# thing : noun
# values : noun
# perfectly : adverb
# once : adverb
# advantage : noun
# case : noun
# Substitution : noun
# Scandal : noun
# also : adverb
# business : noun
# woman : noun
# grabs : noun
# baby : noun
# Now : adverb
# day : noun
# quest : adverb
# rush : noun
# fire : noun
# admirably : adverb
# smoke : noun
# enough : adverb
# nerves : noun
# steel : noun
# beautifully : adverb
# photograph : noun
# recess : noun
# behind : adverb
# panel : noun
# just : adverb
# above : adverb
# right : adverb
# there : adverb
# instant : noun
# glimpse : noun
# half : noun
# rocket : noun
# room : noun
# excuses : noun
# attempt : noun
# photograph : noun
# once : adverb
# narrowly : adverb
# precipitance : noun
# ruin : noun
# now : adverb
# quest : adverb
# practically : adverb
# King : noun
# morrow : noun
# care : noun
# room : noun
# photograph : noun
# satisfaction : noun
# hands : noun
# morning : noun
# so : adverb
# field : noun
# marriage : noun
# life : noun
# habits : noun
# wire : noun
# King : noun
# delay : noun
# Street : noun
# door : noun
# pockets : noun
# night : noun
# Mister : noun
# Holmes : noun
# There : adverb
# people : noun
# pavement : noun
# time : noun
# youth : noun
# voice : noun
# Holmes : noun
# down : adverb
# dimly : adverb
# Now : adverb
# Street : noun
# night : noun
# toast : noun
# coffee : noun
# morning : noun
# King : noun
# Bohemia : noun
# room : noun
# really : adverb
# Holmes : noun
# either : adverb
# shoulder : noun
# eagerly : adverb
# face : noun
# yet : adverb
# Then : adverb
# impatience : noun
# Then : adverb
# matters : noun
# once : adverb
# Holmes : noun
# Yesterday : noun
# lawyer : noun
# love : noun
# future : noun
# annoyance : noun
# husband : noun
# love : noun
# love : noun
# there : adverb
# reason : noun
# s : noun
# yet : adverb
# station : noun
# queen : noun
# silence : noun
# Serpentine : noun
# Avenue : noun
# door : noun
# woman : noun
# steps : noun
# eye : noun
# Holmes : noun
# Holmes : noun
# companion : noun
# rather : adverb
# gaze : noun
# Indeed : adverb
# mistress : noun
# likely : adverb
# morning : noun
# husband : noun
# train : noun
# Charing : noun
# Continent : noun
# Holmes : noun
# back : adverb
# surprise : noun
# Never : adverb
# papers : noun
# King : noun
# hoarsely : adverb
# servant : noun
# room : noun
# King : noun
# furniture : noun
# direction : noun
# shelves : noun
# drawers : noun
# hurriedly : adverb
# flight : noun
# Holmes : noun
# back : adverb
# shutter : noun
# hand : noun
# photograph : noun
# letter : noun
# photograph : noun
# evening : noun
# dress : noun
# letter : noun
# Holmes : noun
# Esq : noun
# friend : noun
# together : adverb
# midnight : noun
# night : noun
# way : noun
# MY : noun
# DEAR : noun
# really : adverb
# very : adverb
# completely : adverb
# fire : noun
# suspicion : noun
# then : adverb
# months : noun
# ago : adverb
# King : noun
# agent : noun
# certainly : adverb
# address : noun
# Yet : adverb
# Even : adverb
# hard : adverb
# evil : noun
# kind : adverb
# clergyman : noun
# actress : noun
# Male : noun
# costume : noun
# often : adverb
# advantage : noun
# freedom : noun
# upstairs : adverb
# clothes : noun
# down : adverb
# just : adverb
# door : noun
# so : adverb
# really : adverb
# object : noun
# interest : noun
# Holmes : noun
# Then : adverb
# rather : adverb
# imprudently : adverb
# night : noun
# husband : noun
# best : adverb
# resource : noun
# flight : noun
# so : adverb
# antagonist : noun
# so : adverb
# nest : noun
# morrow : noun
# photograph : noun
# client : noun
# rest : noun
# peace : noun
# love : noun
# better : adverb
# man : noun
# King : noun
# hindrance : noun
# cruelly : adverb
# only : adverb
# safeguard : noun
# weapon : noun
# always : adverb
# steps : noun
# future : noun
# photograph : noun
# care : noun
# Holmes : noun
# Very : adverb
# truly : adverb
# yours : noun
# IRENE : noun
# ADLER : noun
# woman : noun
# woman : noun
# King : noun
# Bohemia : noun
# epistle : noun
# queen : noun
# pity : noun
# level : noun
# indeed : adverb
# very : adverb
# level : noun
# Holmes : noun
# coldly : adverb
# s : noun
# business : noun
# conclusion : noun
# contrary : adverb
# King : noun
# word : noun
# photograph : noun
# now : adverb
# fire : noun
# so : adverb
# immensely : adverb
# way : noun
# ring : noun
# snake : noun
# ring : noun
# finger : noun
# hand : noun
# value : noun
# even : adverb
# highly : adverb
# Holmes : noun
# name : noun
# photograph : noun
# King : noun
# amazement : noun
# s : noun
# photograph : noun
# Certainly : adverb
# Then : adverb
# there : adverb
# very : adverb
# morning : noun
# away : adverb
# hand : noun
# King : noun
# company : noun
# chambers : noun
# scandal : noun
# kingdom : noun
# Bohemia : noun
# best : adverb
# plans : noun
# Holmes : noun
# woman : noun
# s : noun
# cleverness : noun
# women : noun
# late : adverb
# photograph : noun
# always : adverb
# title : noun
# woman : noun
# ADVENTURE : noun
# II : noun
# LEAGUE : noun
# friend : noun
# Holmes : noun
# day : noun
# autumn : noun
# year : noun
# conversation : noun
# very : adverb
# florid : noun
# gentleman : noun
# hair : noun
# apology : noun
# intrusion : noun
# Holmes : noun
# abruptly : adverb
# room : noun
# door : noun
# behind : adverb
# possibly : adverb
# better : adverb
# time : noun
# Watson : noun
# cordially : adverb
# So : adverb
# Very : adverb
# so : adverb
# Then : adverb
# room : noun
# gentleman : noun
# partner : noun
# helper : noun
# cases : noun
# utmost : adverb
# yours : noun
# also : adverb
# gentleman : noun
# half : noun
# chair : noun
# glance : noun
# eyes : noun
# Holmes : noun
# armchair : noun
# fingertips : noun
# together : adverb
# moods : noun
# Watson : noun
# share : noun
# love : noun
# outside : adverb
# conventions : noun
# humdrum : noun
# everyday : noun
# life : noun
# enthusiasm : noun
# chronicle : noun
# excuse : noun
# so : adverb
# somewhat : adverb
# so : adverb
# adventures : noun
# cases : noun
# indeed : adverb
# interest : noun
# day : noun
# just : adverb
# very : adverb
# problem : noun
# Sutherland : noun
# effects : noun
# combinations : noun
# life : noun
# always : adverb
# far : adverb
# effort : noun
# imagination : noun
# proposition : noun
# liberty : noun
# Doctor : noun
# none : noun
# round : adverb
# otherwise : adverb
# fact : noun
# fact : noun
# reason : noun
# breaks : noun
# down : adverb
# right : adverb
# Now : adverb
# here : adverb
# enough : adverb
# morning : noun
# narrative : noun
# time : noun
# things : noun
# very : adverb
# often : adverb
# crimes : noun
# occasionally : adverb
# indeed : adverb
# there : adverb
# room : noun
# crime : noun
# far : adverb
# case : noun
# instance : noun
# crime : noun
# course : noun
# events : noun
# certainly : adverb
# ever : adverb
# Perhaps : adverb
# kindness : noun
# recommence : noun
# narrative : noun
# merely : adverb
# friend : noun
# Dr : noun
# Watson : noun
# part : noun
# also : adverb
# nature : noun
# story : noun
# detail : noun
# lips : noun
# rule : noun
# indication : noun
# course : noun
# events : noun
# thousands : noun
# cases : noun
# memory : noun
# instance : noun
# best : adverb
# belief : noun
# portly : adverb
# client : noun
# chest : noun
# appearance : noun
# pride : noun
# newspaper : noun
# inside : adverb
# pocket : noun
# down : adverb
# advertisement : noun
# column : noun
# head : noun
# forward : adverb
# paper : noun
# knee : noun
# man : noun
# fashion : noun
# companion : noun
# indications : noun
# dress : noun
# appearance : noun
# gain : noun
# very : adverb
# however : adverb
# inspection : noun
# visitor : noun
# mark : noun
# commonplace : noun
# rather : adverb
# s : noun
# trousers : noun
# frock : noun
# front : noun
# Albert : noun
# chain : noun
# bit : noun
# metal : noun
# down : adverb
# hat : noun
# velvet : noun
# collar : noun
# chair : noun
# beside : adverb
# Altogether : adverb
# there : adverb
# man : noun
# head : noun
# expression : noun
# discontent : noun
# features : noun
# Holmes : noun
# eye : noun
# occupation : noun
# head : noun
# smile : noun
# glances : noun
# time : noun
# labour : noun
# snuff : noun
# Freemason : noun
# amount : noun
# lately : adverb
# else : adverb
# chair : noun
# paper : noun
# eyes : noun
# companion : noun
# name : noun
# Holmes : noun
# example : noun
# labour : noun
# s : noun
# gospel : noun
# ship : noun
# s : noun
# hands : noun
# right : adverb
# hand : noun
# quite : adverb
# size : noun
# muscles : noun
# snuff : noun
# then : adverb
# Freemasonry : noun
# insult : noun
# intelligence : noun
# especially : adverb
# rather : adverb
# rules : noun
# order : noun
# compass : noun
# breastpin : noun
# course : noun
# else : adverb
# right : adverb
# so : adverb
# very : adverb
# inches : noun
# near : adverb
# rest : noun
# desk : noun
# fish : noun
# immediately : adverb
# above : adverb
# right : adverb
# wrist : noun
# only : adverb
# tattoo : adverb
# marks : noun
# even : adverb
# fishes : noun
# scales : noun
# quite : adverb
# addition : noun
# coin : noun
# chain : noun
# even : adverb
# heavily : adverb
# never : adverb
# first : adverb
# there : adverb
# Watson : noun
# Holmes : noun
# magnifico : noun
# reputation : noun
# so : adverb
# advertisement : noun
# now : adverb
# finger : noun
# halfway : adverb
# down : adverb
# column : noun
# Here : adverb
# just : adverb
# paper : noun
# LEAGUE : noun
# account : noun
# late : adverb
# Hopkins : noun
# U : noun
# S : noun
# there : adverb
# now : adverb
# vacancy : noun
# member : noun
# League : noun
# salary : noun
# week : noun
# purely : adverb
# services : noun
# men : noun
# sound : noun
# body : noun
# above : adverb
# age : noun
# years : noun
# person : noun
# clock : noun
# offices : noun
# League : noun
# s : noun
# Court : noun
# Fleet : noun
# Street : noun
# earth : noun
# twice : adverb
# announcement : noun
# Holmes : noun
# chair : noun
# habit : noun
# spirits : noun
# track : noun
# now : adverb
# household : noun
# effect : noun
# advertisement : noun
# fortunes : noun
# first : adverb
# Doctor : noun
# paper : noun
# date : noun
# Morning : noun
# Chronicle : noun
# Just : adverb
# months : noun
# ago : adverb
# Very : adverb
# Now : adverb
# just : adverb
# Holmes : noun
# pawnbroker : noun
# s : noun
# business : noun
# near : adverb
# City : noun
# s : noun
# very : adverb
# late : adverb
# years : noun
# just : adverb
# assistants : noun
# now : adverb
# only : adverb
# job : noun
# half : noun
# wages : noun
# so : adverb
# business : noun
# name : noun
# youth : noun
# Holmes : noun
# name : noun
# s : noun
# youth : noun
# either : adverb
# s : noun
# hard : adverb
# age : noun
# assistant : noun
# Holmes : noun
# very : adverb
# better : adverb
# twice : adverb
# ideas : noun
# head : noun
# indeed : adverb
# market : noun
# price : noun
# experience : noun
# employers : noun
# age : noun
# assistant : noun
# advertisement : noun
# faults : noun
# too : adverb
# Never : adverb
# fellow : noun
# photography : noun
# away : adverb
# camera : noun
# then : adverb
# diving : noun
# down : adverb
# rabbit : noun
# hole : noun
# pictures : noun
# fault : noun
# s : noun
# worker : noun
# There : adverb
# s : noun
# vice : noun
# still : adverb
# girl : noun
# bit : noun
# place : noun
# s : noun
# widower : noun
# never : adverb
# family : noun
# very : adverb
# quietly : adverb
# roof : noun
# heads : noun
# debts : noun
# first : adverb
# thing : noun
# advertisement : noun
# down : adverb
# office : noun
# just : adverb
# day : noun
# weeks : noun
# very : adverb
# paper : noun
# hand : noun
# man : noun
# here : adverb
# s : noun
# vacancy : noun
# League : noun
# Men : noun
# s : noun
# quite : adverb
# man : noun
# there : adverb
# vacancies : noun
# there : adverb
# men : noun
# so : adverb
# trustees : noun
# end : noun
# money : noun
# hair : noun
# only : adverb
# here : adverb
# s : noun
# crib : noun
# then : adverb
# Holmes : noun
# very : adverb
# home : noun
# man : noun
# business : noun
# instead : adverb
# often : adverb
# weeks : noun
# end : noun
# foot : noun
# door : noun
# way : noun
# outside : adverb
# always : adverb
# bit : noun
# news : noun
# never : adverb
# League : noun
# Men : noun
# eyes : noun
# Never : adverb
# vacancies : noun
# merely : adverb
# couple : noun
# year : noun
# work : noun
# very : adverb
# s : noun
# occupations : noun
# easily : adverb
# ears : noun
# business : noun
# years : noun
# couple : noun
# very : adverb
# advertisement : noun
# League : noun
# vacancy : noun
# there : adverb
# address : noun
# particulars : noun
# far : adverb
# League : noun
# millionaire : noun
# Hopkins : noun
# very : adverb
# ways : noun
# men : noun
# so : adverb
# hands : noun
# trustees : noun
# instructions : noun
# interest : noun
# berths : noun
# men : noun
# hair : noun
# very : adverb
# there : adverb
# millions : noun
# men : noun
# so : adverb
# really : adverb
# Londoners : noun
# men : noun
# town : noun
# Then : adverb
# again : adverb
# hair : noun
# Now : adverb
# just : adverb
# perhaps : adverb
# hardly : adverb
# way : noun
# sake : noun
# pounds : noun
# Now : adverb
# fact : noun
# gentlemen : noun
# yourselves : noun
# hair : noun
# very : adverb
# so : adverb
# there : adverb
# competition : noun
# chance : noun
# man : noun
# ever : adverb
# so : adverb
# so : adverb
# just : adverb
# shutters : noun
# day : noun
# right : adverb
# away : adverb
# very : adverb
# holiday : noun
# so : adverb
# business : noun
# address : noun
# advertisement : noun
# never : adverb
# sight : noun
# again : adverb
# Holmes : noun
# north : noun
# man : noun
# hair : noun
# city : noun
# advertisement : noun
# Fleet : noun
# Street : noun
# folk : noun
# s : noun
# Court : noun
# s : noun
# there : adverb
# so : adverb
# country : noun
# together : adverb
# advertisement : noun
# lemon : noun
# brick : noun
# setter : noun
# liver : noun
# clay : noun
# there : adverb
# flame : noun
# despair : noun
# crowd : noun
# right : adverb
# steps : noun
# office : noun
# There : adverb
# stream : noun
# stair : noun
# back : adverb
# soon : adverb
# office : noun
# experience : noun
# Holmes : noun
# client : noun
# memory : noun
# snuff : noun
# very : adverb
# statement : noun
# There : adverb
# office : noun
# couple : noun
# chairs : noun
# deal : noun
# table : noun
# behind : adverb
# man : noun
# head : noun
# even : adverb
# mine : noun
# words : noun
# candidate : noun
# then : adverb
# always : adverb
# fault : noun
# vacancy : noun
# very : adverb
# However : adverb
# man : noun
# others : noun
# door : noun
# so : adverb
# word : noun
# assistant : noun
# vacancy : noun
# League : noun
# admirably : adverb
# requirement : noun
# so : adverb
# backward : adverb
# head : noun
# side : noun
# hair : noun
# quite : adverb
# Then : adverb
# suddenly : adverb
# forward : adverb
# hand : noun
# warmly : adverb
# success : noun
# injustice : noun
# however : adverb
# excuse : noun
# precaution : noun
# hair : noun
# hands : noun
# There : adverb
# water : noun
# eyes : noun
# twice : adverb
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-083f4e37f9d6> in <module>()
#      10         lines = re.findall(words_pattern, text, flags=re.IGNORECASE)
#      11         for line in lines:
# ---> 12             line = nlp(line)
#      13             for token in line:
#      14               if spacy.explain(token.pos_)=='noun' or spacy.explain(token.pos_)=='adverb':
#
# /usr/local/lib/python3.7/dist-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#    1018                 error_handler = proc.get_error_handler()
#    1019             try:
# -> 1020                 doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1021             except KeyError as e:
#    1022                 # This typically happens if a component is not initialized
#
# /usr/local/lib/python3.7/dist-packages/spacy/pipeline/trainable_pipe.pyx in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
#
# /usr/local/lib/python3.7/dist-packages/spacy/pipeline/transition_parser.pyx in spacy.pipeline.transition_parser.Parser.predict()
#
# /usr/local/lib/python3.7/dist-packages/spacy/pipeline/transition_parser.pyx in spacy.pipeline.transition_parser.Parser.greedy_parse()
#
# /usr/local/lib/python3.7/dist-packages/thinc/model.py in predict(self, X)
#     313         only the output, instead of the `(output, callback)` tuple.
#     314         """
# --> 315         return self._func(self, X, is_train=False)[0]
#     316
#     317     def finish_update(self, optimizer: Optimizer) -> None:
#
# /usr/local/lib/python3.7/dist-packages/spacy/ml/tb_framework.py in forward(model, X, is_train)
#      36         unseen_classes=model.attrs["unseen_classes"],
#      37         train=is_train,
# ---> 38         has_upper=model.attrs["has_upper"],
#      39     )
#      40
#
# /usr/local/lib/python3.7/dist-packages/spacy/ml/parser_model.pyx in spacy.ml.parser_model.ParserStepModel.__init__()
#
# /usr/local/lib/python3.7/dist-packages/thinc/model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /usr/local/lib/python3.7/dist-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# /usr/local/lib/python3.7/dist-packages/thinc/model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /usr/local/lib/python3.7/dist-packages/thinc/layers/list2array.py in forward(model, Xs, is_train)
#      25         return model.ops.unflatten(dY, lengths)  # type: ignore
#      26
# ---> 27     return model.ops.flatten(Xs), backprop  # type: ignore
#
# /usr/local/lib/python3.7/dist-packages/thinc/backends/ops.py in flatten(self, X, dtype, pad, ndim_if_empty)
#     248             padded.append(xp.zeros((pad,) + x.shape[1:], dtype=x.dtype))
#     249             X = padded
# --> 250         result = xp.concatenate(X)
#     251         if dtype is not None:
#     252             result = xp.asarray(result, dtype=dtype)
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:
